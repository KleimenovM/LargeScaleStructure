# %%
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

import pandas as pd

from astropy.io import fits
from astropy.table import Table

# %%
data_all = fits.open("galaxy_DR12v5_LOWZ_North.fits.gz")
data_all.info()

data = data_all[1].data
# Out:
# Filename: galaxy_DR12v5_LOWZ_North.fits.gz
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1                1 BinTableHDU     92   317780R x 42C   [D, D, J, 12A, J, J, J, J, J, J, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, E, 5E, E, 5E, J, E, E, E, E, E, E, E, E, E, J, J, J, J, 3I, J, J, J, J]

# %%
ra  = np.array(data["RA"], dtype=np.float32)
dec = np.array(data["DEC"], dtype=np.float32)
z   = np.array(data["Z"], dtype=np.float32)

# %%
np.savez("galaxy_north_reduced.npz", ra=ra, dec=dec, z=z)
